# %% [markdown]
# # LCDM Documentaion - GSoC 2014

# %% [markdown]
# ### Time delays in lensed galaxies and finding strong lenses in astronomical images

# %% [markdown]
# This project consists of two parts. The first part is to apply new strong gravitational lensing time delay measurements which can enable constraints on dark energy. Quasar variability can be used to measure the time delay between two or more quasar images in a strongly lensed system. To achieve precision cosmological constraints, the error on this measurement needs to be reduced. The distance correlation approach hopes to reduce this error for finding time delays. The second part is to perform identification of strong gravitational lenses in Images.

# %% [markdown]
# ### 1. Time delays in gravitationally lensed galaxies

# %% [markdown]
# The following parts are covered:
#
# a. Coding the Distance Correlation method
#
# b. Finding the time shift between two curves
#
# c. Lightcurve generating framework
#
# d. Addional framework for drawing and exporting bezier curves

# %% [markdown]
# #### a. Coding the distance correlation method

# %% [markdown]
# The project uses distance correlation technique to estimate the time delay between two curves. "dcor.py" file contains the class implementing it. It takes as input two vectors of equal length and returns the corresponding distance correlation.

# %%
import math
import numpy as np

'''
A Class for calculating the distance correlation beween two vectors of 'same' size.
Constructor    :     dcor(X,Y)                Returns an object of dcor class. X and Y are input vectors.
Functions      :     find_correlation()        Returns the distance correlation.
'''

class dcor:
    def __init__(self, X, Y):
        X_Mat = np.zeros((len(X),len(X)))               # X distance matrix - for all pairwise distances in X 
        Y_Mat = np.zeros((len(X),len(X)))               # Y distance matrix - for all pairwise distances in Y
        D_X_Mat = np.zeros((len(X),len(X)))             # X doubly centered distance matrix
        D_Y_Mat = np.zeros((len(X),len(X)))             # Y doubly centered distance matrix
        X_Row_Sum = np.zeros(len(X))                    # i'th Row sum of X distance matrix
        Y_Row_Sum = np.zeros(len(X))                    # i'th Row sum of Y distance matrix
        X_Col_Sum = np.zeros(len(X))                    # i'th Col sum of X distance matrix
        Y_Col_Sum = np.zeros(len(X))                    # i'th Col sum of Y distance matrix
        self.dCor = -1                                  # class variable - Correlation between X and Y

        if(len(X)!=len(Y)):                             # Check for same size of X and Y
            print "Distance Correlation: Input vectors must be of same size -"+str(len(X))+" != "+str(len(Y))
            return -1    
        
        if(len(X)==0):                                  # If Empty
            print "Distance Correlation: Input vector empty"
            return -1        
        
        for i in range (0,len(X)):
            sum_r_x = 0
            sum_r_y = 0            
            for j in range (0,len(X)):
                sum_r_x = sum_r_x + abs( X[i] - X[j])            # Adding sum to find the row mean 
                sum_r_y = sum_r_y + abs( Y[i] - Y[j])                 
                X_Mat[i][j] = ( abs( X[i] - X[j])  )            # Eucledian norm equivalent to modulus here
                Y_Mat[i][j] = ( abs( Y[i] - Y[j])  )
            
            X_Row_Sum[i] = sum_r_x     
            Y_Row_Sum[i] = sum_r_y     

        for i in range (0,len(X)):                                # Finding the column mean
            sum_c_x = 0
            sum_c_y = 0            
            for j in range (0, len(X)):
                 sum_c_x += X_Mat[j][i]        
                 sum_c_y += Y_Mat[j][i]
            X_Col_Sum[i] = sum_c_x
            Y_Col_Sum[i] = sum_c_y             


        X_mean = sum(X_Row_Sum) / (len(X) ** 2.0)                    # Overall mean equivalent to sum of all row sums  
        Y_mean = sum(Y_Row_Sum) / (len(X) ** 2.0)                    # divided by total number of elements i.e. n^2

        for i in range (0,len(X)):
            for j in range (0, len(X)):                             # Forming doubly centered distance matrix - cast len(X) to float for div.
                D_X_Mat[i][j] = ( X_Mat[i][j] - X_Row_Sum[i] / float(len(X)) - X_Col_Sum[j] / float(len(X)) + X_mean )
                D_Y_Mat[i][j] = ( Y_Mat[i][j] - Y_Row_Sum[i] / float(len(X)) - Y_Col_Sum[j] / float(len(X)) + Y_mean )

        Sum_Cov = 0
        Sum_Var_X = 0
        Sum_Var_Y = 0
        for i in range (0,len(X)):
            for j in range (0, len(X)):
                Sum_Cov     = Sum_Cov     + D_X_Mat[i][j] * D_Y_Mat[i][j]
                Sum_Var_X    = Sum_Var_X    + D_X_Mat[i][j] * D_X_Mat[i][j]
                Sum_Var_Y     = Sum_Var_Y    + D_Y_Mat[i][j] * D_Y_Mat[i][j]
        
        dCov       = Sum_Cov   / (len(X) ** 2.0)
        dVar_X     = Sum_Var_X / (len(X) ** 2.0)
        dVar_Y     = Sum_Var_Y / (len(X) ** 2.0)
     
        self.dCor = dCov / math.sqrt( dVar_X * dVar_Y)

    def find_correlation(self):
        return self.dCor

# %% [markdown]
# The code uses numpy arrays for faster matrix operations. The following examples shows a simple use case.

# %%
'''Example'''
A = [3,4,5,6]
B = [4,5,6,7]
print dcor(A,B).find_correlation()
# Out:
# 1.0

# %% [markdown]
# Distance correlation is insensitive to uniform scale changes in a direction - hence the correlation between A and B is 1.

# %% [markdown]
# #### b. Finding shifts in lightcurves

# %% [markdown]
# The objective is to input a file containing data of two or more curves and find the shift between them. Correlation between curves is calculated for each shift iteration and the value corresponding to maximum correlation is taken as the shift between curves. The light curves are input as plain text files with each row in the format
#
# {mhjd-date [Mag(Curve i) Err(Curve i)] for i curves}
#
# corr_plot.py has functions to load, segment, plot and estimate the shift between two light curves.
#
# For loading the data - use the load_data() function. It loads the first argument passed from the terminal and returns the curve and the time data. For plotting and finding correlation, extract the 2 light curves of interest. The spline fitting can be done with fit_curve function. MAX_GAP parameter contols maximum days of non observance after which segments will be disjointed. plot_data_points function plots the input data points. plot_segment function plots a segment object. Both functions have a parameter to offset the plot by the given units in Y direction. A sample plotting routine will look like:
#
# time, Lcurves = load_data()
#
# LC_1, LC_2, T_Segments = fit_curve(time, lc_1, lc_2, MAX_GAP) #lc_1 and lc_2 are the curves points of interest extracted from Lcurves
#
# plot_data_points(time, lc_1, lc_2, avg[x], avg[x+1])

# %%
from IPython.display import Image
Image(filename='segements_max_60.png')

# %% [markdown]
# To find the shift between two curves use - find_shift(LC_1, LC_2, Max_Shift, Shift_Step) which returns the shift in mhjd days.
# Here LC_1 and LC_2 are two lists of 'SEGMENT' objects. The 'Max_Shift' specifies the maximum amount of days one curve can be shifted with respect to another. 'Shift_Step' controls the granuality of successive increments.
#
# Two types of fitting have been implemented - the univariate spline fitting to the segments and a cubic polynomial fitting to segments. The cubic polynomial fitting can be found in corr_plot_diff_algo.py
#
# A description of the classes and functions is as follows:
#
# <b>class Segment(object):</b> Class for light curve segment - used for simulating a contiguous lc section.
#
# <u>Members:</u>
#
# intensity_function - Interpolating function of the segment
#
# time_start - Starting time of the segment (minimum of time_data)
#
# time_end - End time of the segment (maximum of time_data)
#
# time_data - List of points in time domain where the segment was sampled
#
# intensity - Intensity values corresponding to time_data
#
# time_data and intensity are stored to re-evaluate the fitting function after a transformation on data points.
#
# <u>Functions:</u>
#
# shift_segment(days) - Shifts a segment by the given number of mhjd days. The interpolating function is re-evaluated.
#
# intersection(segment) - Returns a list of intensities corresponding to temporal overlap of the passed segment with the segment it is called upon.
#
# getIntensity(time) - Returns the intensitiy at a given time by evaluating the interpolating function.
#
# getStartTime() - Returns the start time of the segment.
#
# getEndTime() - Returns the end time of a segment.
#
# getSegmentLength() - Returns the length of the segment.
#
# display() - Displayes the parameters of the light segment.
#
# <b>Public Functions</b>
#
# load_data() - Returns a lists of elements having the format [ Time, [[Lightcurve Ai, Error in Ai] for i curves]]. Header of input file is ignored (first two lines).
#
# plot_data_points(time, lc_a, lc_b, offset1, offset2): Plots a pair of LC data points offset in amplitude by the given amounts.
#
# plot_segment(LC, avg): Plots a light curve segment offset by a given amount.
#
# show_plots(): Displays all the plots.
#
# find_shift(LC_1, LC_2, Max_Shift, Shift_Step): Finds the shift between two light curves. This function shifts all the segments in a light curve by an amount 'Shift_Step' till the Max_Shift and for each configuration finds the intersections between the curve segments. The correlation between them is recorded and the shift corresponding to maximum correlation is output.
#
# fit_curve(time, lc_a, lc_b, MAX_GAP): Takes a pair of raw light curve intensity values and returns a list of 'Segment' Objects - each Segment object has its own interpolating function. MAX_GAP corresponds to the number of non observational days after which the segment will terminate. Each segment should have a minimum of 5 observational points.
#
# <u>Summary:</u>
#
# 1. Load data using 'load_data()' function.
# 2. Extract the light curves of interest.
# 3. Fit segments using 'fit_curve()' function on the extracted light curves.
# 4. Find the shift using 'find_shift()' function on the light segments.
# 5. Plot using 'plot_segment()', 'plot_data_points()' and 'show_plots()' function.

# %% [markdown]
# #### c. Generating artificial lightcurves

# %% [markdown]
# The objective is to generate a suite of light curves to test the distance correlation approach. 'lc_gen.py' has a suite of parameters that can be modified to generate a light curve. It has options for imprinting random seasonal and non observable effects. After the imprinting of effects - we can save the data in a file for testing.
#
# An example run might be:
#
# LC = l_curve(mass, radius, alpha, b, sigma, tsteps) # Generates the light curve according to given parameters
#
# S = LC.addSeasonalEffects(Flux1, error1, time1, Flux2, error2, time2, tsteps) # time1 and time2 are the associated times with LC's
#
# D = LC.addDailyEffects(S)
#
# plot_data(S)
#
# generateFile('Artificial_LC.rdb',S)
#
# The first example plots a file with less shift, the second shifts a curve by larger amount.

# %%
Image(filename='lc_gen1.png')

# %%
Image(filename='shift_70.png')

# %% [markdown]
# A description of the classes and functions is as follows:
#
# <b>class l_curve(object):</b> A Class for generating a pair of light curves.
#
# <u>Members:</u>
#
# Curve: For storing the thermal, orbital and crossing curves.
#
# <u>Functions:</u>
#
# stochasticIntegral(): Returns the integral for a given t value.
#
# initTimescales(): Returns the timescales for Thermal, Orbital and Crossing curves.
#
# getCurve(): Returns a list of Thermal, Orbital and Light Crossing Curve.
#
# getThermalCurve(): Returns the thermal Light Curve.
#
# getOrbitalCurve(): Returns the Orbital Curve.
#
# getLightCrossCurve(): Returns the Light Crossing Curve.
#
# display(): Displays the curve points data.
#
# getError(): Returns a list of error values for a given mean and variance.
#
# getTimes(): Returns a list of time values from a start time.
#
# addSeasonalEffects(): Adds seasonal effects corresponding to long periods of non-observability.
#
# addDailyEffects(): Adds random daily non observatioinal effects.
#
# <b>Public functions</b>
#
# generateFile(filename, Data): Writes the generated curve data to a file.
#
# \#--------------------------------------------------------------------
# \# List of parameters and default values
# \#--------------------------------------------------------------------
#
# tsteps = 1024
#
# mass = 1.0E8
#
# radius = 100
#
# sigma = 1.0
#
# b = 0.
#
# alpha = 0.01
#
# \#Imprint effects
#
# \#Starting date of observations
#
# mhjd = 50000
#
# \#Maximum shift between the two curves. A shift will be selected at random between range 0 to Max_Shift. MAXIMUM SHIFT SHOULD BE LESS THAN THE T_STEPS
#
# Max_Shift = 750
#
# \#Difference in days between two observations
#
# Days_diff = 1
#
# \#Seasonal difference in days between observations
#
# Seasonal_diff = 90
#
# \#Probability of a seasonal effect being imprinted
#
# Prob_Seasonal = 0.01
#
# \#Probability of a day being non- observable
#
# Prob_Day = 0.10
#
# \#Curve Offsets (values added to returned intensities)
#
# Offset1 = 0
#
# Offset2 = 0
#
# \#Mean and variance in observational errors of light-curves
#
# Mean_error_1 = 0.00418616252822
#
# Mean_error_2 = 0.00543952595937
#
# Variance_1 	 = 0.000107790282228
#
# Variance_2	 = 0.000155465436713
#
# <u>Summary:</u>
#
# 1. Make object of l_curve class.
# 2. Extract the fluxes, times and errors.
# 3. Imprint seasonal effects.
# 4. Imprint daily effects.
# 5. Save to a file.

# %% [markdown]
# #### d. Drawing and exporting bezier curves

# %% [markdown]
# The objective is to generate custom ligt curves for testing. The functions are in 'lc_b.py' file. The code promts a user to give the range of the axes and the number of control points on the curve. A plot is presented where a user can pick his control points and a bezier curve is drawn using them. The two Bezier curves can be saved to a file using 'trimCurve' function that selects the common bezier segments followed by 'generateFile' function. This output file can be used for calculation the distance correlation as described above.
# The following figures show some examples of generated curves.

# %%
Image(filename='bezier_diff_50.png')

# %%
Image(filename='bezier_same.png')

# %% [markdown]
# A description of the functions is as follows:
#
# <b>Public functions</b>
#
# C_factory(): Returns a b-spline curve.
#
# make_knot_vector(): Returns a knot vector for use in C_factory().
#
# basis_factory(): Returns basis for C_factory().
#
# generateFile(): Outputs curve data to a file.
#
# trimCurve(): Extracts the common areas of the curves.
#
# getError(): Returns a error list drawn from a normal distribution of given mean and variance.
#
# plot_data_points(): Plots the bezier curve.
#
# show_plots(): Shows the plots.
#
# <u>Summary:</u>
#
# 1. Draw the bezier curves.
# 2. Find the bezier functions.
# 3. Store data in a file.
# 4. Analyze using corr_plot.py.

# %% [markdown]
# ### 2. Strong Lenses in Astronomical Images

# %% [markdown]
# An attempt was made to find strong lenses in images using a technique similar to PCA based lens finder. The main steps are to fit a model(Sersic or MOG's) to the galaxy profile and subract it - analyze the residual through a transformation to polar coordinates by looking for peaks in median row intensity values.
#
# Primarily three methods were explored.
#
# a. polar.py - implements the procedure of transforming the image to polar coordinates about the galaxy's center and plotting the median row intensity values. A sersic profile is fitted using scipy.optimize library.
#
# <b>Public Functions</b>
#
# plot_polar_image(): Plots an image reprojected into polar coordinates.
#
# index_coords(): Creates x & y coords for the indicies in a numpy array
#
# cart2polar(): Transforms from cartesian to polar space.
#
# polar2cart(): Transforms from polar to cartesian space.
#
# reproject_image_into_polar(): Projects a numpy array into a polar coordinate system.
#
# sersic(): Template sersic function.
#
# get_statistics(): Returns the row median and mean.
#
# fit_profile(): Returns a sersic model fit to the data.
#
# <u>Summary</u>:
#
# 1. Read image usinf scipy.misc.imread()
# 2. Transform to polar coordinates about the center.
# 3. Get the statistics.
# 4. Use fit_profile() function and plot results.

# %%
Image(filename='arc.JPG')

# %%
Image(filename='Seresic_Profile_radial.png')

# %%
Image(filename='Seresic_Profile.png')

# %% [markdown]
#  b. In second method - convert an image into polar coordinates about a 'chosen pixel', then find the row mean in the transform for each row. On these row means, fit a serisic profile, and the 'real center' will be the one which has maximum correlation between the fitted seresic profile and the row means. Vary the 'chosen pixel' for all image pixels. This method returns incorrect centers. The center returned by this method is the green dot towards the right.

# %%
Image(filename='arc0.png')

# %% [markdown]
# c. Direct 2D fits - For these many options were explored including PyMix, PyMc, Galfit, scipy optimize, griffin shapelets and astropy and others. The objective is to fit a 2D profile directly and subtract it to get the residual.
# Scipy optimize was tried for gaussian and sersic fuctions. While the gaussian functions converged for a good initial estimate - the sersic profile could not be converged.

# %%
Image(filename='scipy_gauss_fit.jpg')

# %% [markdown]
# The right figure shows the original image - the left one is after subtracting a 2D gaussian. Since a gaussian decays very slowly - a single gaussian cannot accurately fit a decaying exponental (like sersic). Even though there is some reduction in the intensity it is not perfect.
#
# Another option was to try a mixture of gaussians through PyMix. A drawback with PyMix is that it does not tell the optinum number of gaussians to estimate our data with. Pymc does not have MOG's. Galfit was tried but its source code is not available. Shapelets by griffin were tried. Astropy fittings did not have a sersic function implementation.

# %%
Image(filename='griffin_shapelets.png')

# %% [markdown]
# ## Testing on Artificial Light Curves

# %% [markdown]
# Testing on artificial light curves was done and the code returned good estimates of the shift - excluding the cases where the seasonal effects wiped more than about 50% of the observations on large shifts relative to the light curve length (which is tricky anyways). Care should always be taken that high shifts in two light curves will include less and less overlap points - causing the correlation to be higher sometimes; giving false results. Hence the maximum allowed shift should be kept small so that sufficient number of overlap points are there as a meaure of confidence.
#
# Some test cases are:

# %% [markdown]
# a. Small shift with less seasonal effects - a file with a shift of 9 days is generated which is predicted correctly.

# %%
Image(filename='shift_9_result_9.png')

# %% [markdown]
# b. Large shift with less seasonal effects - a shift of 365 days is recovered corectly.

# %%
Image(filename='shift_365_result_365.png')

# %% [markdown]
# c. Medium shift with high seasonal effects - a shift of 134 days is reported incorrectly as 89 days. As the graph suggests - there are less observational data points - some disjointed data points don't form a segment as they have less than 5 observational points.

# %%
Image(filename='shift_134_result_89.png')

# %% [markdown]
# ## Testing on Real Light Curves

# %% [markdown]
# The test results for Courbin are included.

# %% [markdown]
# AB - 18 mhjd days with correlation 0.930971031463
#
# BC - 0 mhjd days with correlation 0.880074166126
#
# CD - 7 mhjd days with correlation 0.855339246734
#
# BD - 8 mhjd days with correlation 0.954308442358
#
# AD - 9 mhjd days with correlation 0.907725297782
#
# AC - 19 mhjd days with correlation 0.927082742855
#
# The correlation graph for BC case is as shown.

# %%
Image(filename='corr_BC.png')

# %% [raw]
# Testing for J1001_Rathnakumar2013 returned a time shift of 114 days (119 given on cosmograil).
