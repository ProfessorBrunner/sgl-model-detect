# %% [markdown]
# This is the documentation for the sgl-model-detect module. It has a variety of use options, so it can seem a little complicated at first. I think this guide will make it a lot more clear!
#
# The main module that does all the heavy lifting is modelImages.py. It is implemented using python's argparse module to control the command line inputs. So, to see the details of the inputs, run the following.

# %%
# %%bash
# python ../src/modelImages.py -h
# Out:
# usage: modelImages.py [-h] [--fixedCenters] [--showImages] [--cutout]
#                       [--cutoutData] [--subtraction] [--subtractionData]
#                       [--chain]
#                       filename centers output modeler n_walkers format
#                       primaryBand [secondaryBand]
#
# This program models the light profile of a galaxy in a fits image using a
# Mixture-of-Gaussian model. It can use either MCMC or non-linear least squares.
#
# positional arguments:
#   filename           Either a fits filename or a directory of files. NOTE: The
#                      GUI will not allow you to choose a directory. Choose a
#                      file and edit the text.
#   centers            Either a filename or a comma separate pair of coordinates
#                      for x,y.
#   output             Location to store the programs output.
#   modeler            Modeler used to perform fit. Either MCMC or NLSQ.
#   n_walkers          Number of walkers to use in the MCMC sampler. If NLSQ is
#                      chosen choice does not matter. Multiples of 500 up to
#                      4000 allowed.
#   format             The format of images to use. Choice of CFHTLS, SDSS or
#                      Toy
#   primaryBand        What band to use in the fit. Choice of u,g,r,i,z, or t
#   secondaryBand      Optional. If option other than 'None' chosen, will
#                      subtract a scaled version of the model in primary band
#                      from this one and search for lens residuls.
#
# optional arguments:
#   -h, --help         show this help message and exit
#   --fixedCenters     Use the given centers as fixed values. Otherwise, they
#                      will be treated as initial guesses
#   --showImages       Show images rather than save them to file.
#   --cutout           Save a .png of the original cutout to file.
#   --cutoutData       Save the raw data of the cutout to file.
#   --subtraction      Store a .png of the model subtraction from the original
#                      image.
#   --subtractionData  Save the raw image data to file of the residuals.
#   --chain            Store the markov chain in the output directory. OCCUPIES
#                      A LOT OF FILESPACE.

# %% [markdown]
# So, an example test of the program would be the following. Let's look at each of them one by one.
#
# * **Optional arguments:** The first thing after the name of the script is the optional arguments, indicated by '--'. Any of the ones shown above as optional arguments can be called. In this case, I've called the option that will display the plots the modeler makes. The rest are fairly self-explanatory.
# * **Filename:** The first required arguement is the filename. This is either the name of one particular fits file or a directory of many images. If just one file is given, one that particular image will be fit (but possibly in more than one band - more on that in a second). If a whole directory is given, it will attempt to fit the whole directory of .fits images.
# * **Centers:** The modeler needs to know where the galaxy of interest is in the image. This file contains the unique identifier of the galaxy and the image coordinates for it. The exact format is given to the program by the format argument. If you have images without image coordinates, the makeCenterFile.py file may be able to help genreate one.
# * **Output:** The program needs a place to save it's outputs. For each galaxy, the program will create a folder within this directory and store all outputs there. The program automatically makes a plot of the model v. the original image, plots a histogram of the sample chain (MCMC only) and storess its final model decision. It can also save single images, their raw numpy data, and the entire sample chain (MCMC only).
#
# * **Modeler:** The program is built to use 2 different modeling approaches. The options are Markov Chain Monte Carlo (MCMC) and Non-linear Least Squares (NLSQ).
# * **N Walkers:** The specific MCMC implementation used in this program allwos a variable number of walkers. More walkers will improve convergence, at the expense of time and memory. Unfortunately, an option needs to be entered even if NLSQ is chosen; it will not be used.
# * **Format:** The format of image being entered. Will determine how centers are read and how unique IDs are gleaned from filenames.
# * **Primary Band:** The band to use in the fit. The modeler will take that image and attempt to fit to it.
# * **Secondary Band:** [Optional] If one is provided, after the modeler fits to primary band it will subtract a scaled version of that model from the secondary band image.

# %%
# %%bash
# mkdir ~/Documents/Research/Output
# python ../src/modelImages.py --showImages ../data/simulated_lenses/CFHTLS_072_2003_i.fits ../data/simulated_lenses/galw1catalog ~/Documents/Research/Output MCMC 1000 CFHTLS i
# Out:
# ------------------------------
# ******************************
# ______________________________
# Image ID : 072_2003
# Fitting now
# Fitting Time: 25.1702 Seconds
# Chain Size: 13 Megabytes
# BE: -131691186.392344	dBE/BE: 0.002151
# BE Calculation time: 8.373061 Seconds
# 1 Gaussian Model
#
# Center:	 (14.25, 14.13)
#
# Gaussian 1:
# Amplitude 1:	330.739
# VarX 1:	25.451
# VarY 1:	20.963
# Corr 1:	0.110
#
#
# ----------------------------------------
# Max Gaussians = 7
# Fitting Time: 40.8824 Seconds
# Chain Size: 22 Megabytes
# BE: -124200916.474600	dBE/BE: 1.128357
# BE Calculation time: 18.382452 Seconds
# 2 Gaussians Model
#
# Center:	 (14.25, 14.13)
#
# Gaussian 1:
# Amplitude 1:	273.172
# VarX 1:	25.313
# VarY 1:	21.537
# Corr 1:	0.131
#
# Gaussian 2:
# Amplitude 2:	86.861
# VarX 2:	7.968
# VarY 2:	7.546
# Corr 2:	-0.111
#
#
# ----------------------------------------
# Old BE: -131691186.392	 New BE: -124200916.475
# Fitting Time: 36.1513 Seconds
# Chain Size: 32 Megabytes
# BE: -752575790.697512	dBE/BE: 3.899715
# BE Calculation time: 28.725179 Seconds
# 2 Gaussians Model
#
# Center:	 (14.32, 14.03)
#
# Gaussian 1:
# Amplitude 1:	369.308
# VarX 1:	9.215
# VarY 1:	8.049
# Corr 1:	0.085
#
# Gaussian 2:
# Amplitude 2:	164.598
# VarX 2:	3.878
# VarY 2:	2.149
# Corr 2:	-0.156
#
# Gaussian 3:
# Amplitude 3:	-22.316
# VarX 3:	3.152
# VarY 3:	5.069
# Corr 3:	0.297
#
#
# ----------------------------------------
# Old BE: -124200916.475	 New BE: -752575790.698
# Best model N = 2
# SSR = 2.266291e+05
# chi2dof = 48.736
# mkdir: cannot create directory ‘/home/sean/Documents/Research/Output’: File exists

# %% [markdown]
# And that's all there is to it! Here's a few more examples to solidy the options available.
#
# This one will do a NLSQ fit on a different simulated lens, and also show the residual after lens identification.

# %%
# %%bash
# python ../src/modelImages.py --showImages --subtraction ../data/simulated_lenses/CFHTLS_047_0155_i.fits ../data/simulated_lenses/galw1catalog ~/Documents/Research/Output NLSQ 1000 CFHTLS i g
# Out:
# ------------------------------
# ******************************
# ______________________________
# Image ID : 047_0155
# Fitting now
# SSR = 6.308642e+05
# chi2dof = 38.945
# 1 Gaussian Model
#
# Center:	 (14.25, 14.63)
#
# Gaussian 1:
# Amplitude 1:	398.484
# VarX 1:	28.221
# VarY 1:	24.832
# Corr 1:	-0.126
#
#
# ----------------------------------------
# Max Gaussians = 8
# SSR = 4.228874e+04
# chi2dof = 0.921
# 2 Gaussians Model
#
# Center:	 (14.24, 14.58)
#
# Gaussian 1:
# Amplitude 1:	205.173
# VarX 1:	53.427
# VarY 1:	48.090
# Corr 1:	-0.170
#
# Gaussian 2:
# Amplitude 2:	352.629
# VarX 2:	6.594
# VarY 2:	5.321
# Corr 2:	-0.023
#
#
# ----------------------------------------
# Old BE: 38.945	 New BE: 0.921
# SSR = 3.937450e+04
# chi2dof = 0.782
# 2 Gaussians Model
#
# Center:	 (14.23, 14.58)
#
# Gaussian 1:
# Amplitude 1:	201.482
# VarX 1:	53.834
# VarY 1:	48.402
# Corr 1:	-0.193
#
# Gaussian 2:
# Amplitude 2:	339.186
# VarX 2:	6.761
# VarY 2:	5.382
# Corr 2:	-0.085
#
# Gaussian 3:
# Amplitude 3:	18.706
# VarX 3:	35.608
# VarY 3:	35.921
# Corr 3:	0.945
#
#
# ----------------------------------------
# Old BE: 0.921	 New BE: 0.782
# Best model N = 2
# SSR = 4.228874e+04
# chi2dof = 0.921
# The image 047_0155 represents a lens: True
# ../src/modelImages.py:368: DeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   prim_fit_scaled = prim_fit*imageObj[secondaryBand][c]/imageObj[primaryBand][c]

# %% [markdown]
# This one models the whole simulated lens directory, and doesn't show images.

# %%
# %%bash
# python ../src/modelImages.py ../data/simulated_lenses/ ../data/simulated_lenses/galw1catalog ~/Documents/Research/Output NLSQ 1000 CFHTLS i
# Out:
# ------------------------------
# ******************************
# ______________________________
# Image ID : 047_1845
# Fitting now
# SSR = 2.037849e+05
# chi2dof = 3207.380
# 1 Gaussian Model
#
# Center:	 (14.88, 13.78)
#
# Gaussian 1:
# Amplitude 1:	245.291
# VarX 1:	12.605
# VarY 1:	15.425
# Corr 1:	0.035
#
#
# ----------------------------------------
# Max Gaussians = 4
# SSR = 8.253034e+04
# chi2dof = 13.246
# 2 Gaussians Model
#
# Center:	 (14.76, 14.03)
#
# Gaussian 1:
# Amplitude 1:	119.322
# VarX 1:	26.989
# VarY 1:	29.302
# Corr 1:	-0.047
#
# Gaussian 2:
# Amplitude 2:	222.474
# VarX 2:	3.023
# VarY 2:	3.717
# Corr 2:	0.162
#
#
# ----------------------------------------
# Old BE: 3207.380	 New BE: 13.246
# SSR = 7.336695e+04
# chi2dof = 14.653
# 2 Gaussians Model
#
# Center:	 (14.78, 14.02)
#
# Gaussian 1:
# Amplitude 1:	102.935
# VarX 1:	32.222
# VarY 1:	27.494
# Corr 1:	-0.103
#
# Gaussian 2:
# Amplitude 2:	61.864
# VarX 2:	2.845
# VarY 2:	25.684
# Corr 2:	0.437
#
# Gaussian 3:
# Amplitude 3:	177.062
# VarX 3:	4.179
# VarY 3:	2.648
# Corr 3:	0.104
#
#
# ----------------------------------------
# Old BE: 13.246	 New BE: 14.653
# Best model N = 2
# SSR = 8.253034e+04
# chi2dof = 13.246
# ------------------------------
# ******************************
# ______________________________
# Image ID : 047_0155
# Fitting now
# SSR = 6.308642e+05
# chi2dof = 38.945
# 1 Gaussian Model
#
# Center:	 (14.25, 14.63)
#
# Gaussian 1:
# Amplitude 1:	398.484
# VarX 1:	28.221
# VarY 1:	24.832
# Corr 1:	-0.126
#
#
# ----------------------------------------
# Max Gaussians = 8
# SSR = 4.228874e+04
# chi2dof = 0.921
# 2 Gaussians Model
#
# Center:	 (14.24, 14.58)
#
# Gaussian 1:
# Amplitude 1:	205.173
# VarX 1:	53.427
# VarY 1:	48.090
# Corr 1:	-0.170
#
# Gaussian 2:
# Amplitude 2:	352.629
# VarX 2:	6.594
# VarY 2:	5.321
# Corr 2:	-0.023
#
#
# ----------------------------------------
# Old BE: 38.945	 New BE: 0.921
# SSR = 3.937450e+04
# chi2dof = 0.782
# 2 Gaussians Model
#
# Center:	 (14.23, 14.58)
#
# Gaussian 1:
# Amplitude 1:	201.482
# VarX 1:	53.834
# VarY 1:	48.402
# Corr 1:	-0.193
#
# Gaussian 2:
# Amplitude 2:	339.186
# VarX 2:	6.761
# VarY 2:	5.382
# Corr 2:	-0.085
#
# Gaussian 3:
# Amplitude 3:	18.706
# VarX 3:	35.608
# VarY 3:	35.921
# Corr 3:	0.945
#
#
# ----------------------------------------
# Old BE: 0.921	 New BE: 0.782
# Best model N = 2
# SSR = 4.228874e+04
# chi2dof = 0.921
# ------------------------------
# ******************************
# ______________________________
# Image ID : 047_0988
# Fitting now
# SSR = 1.169413e+05
# chi2dof = 9.240
# 1 Gaussian Model
#
# Center:	 (11.67, 16.79)
#
# Gaussian 1:
# Amplitude 1:	53.781
# VarX 1:	43.493
# VarY 1:	46.362
# Corr 1:	-0.369
#
#
# ----------------------------------------
# Max Gaussians = 10
# SSR = 1.169413e+05
# chi2dof = 9.282
# 2 Gaussians Model
#
# Center:	 (11.67, 16.79)
#
# Gaussian 1:
# Amplitude 1:	53.781
# VarX 1:	43.495
# VarY 1:	46.364
# Corr 1:	-0.369
#
# Gaussian 2:
# Amplitude 2:	15.514
# VarX 2:	0.000
# VarY 2:	1.798
# Corr 2:	-0.084
#
#
# ----------------------------------------
# Old BE: 9.240	 New BE: 9.282
# Best model N = 1
# SSR = 1.169413e+05
# chi2dof = 9.240
# ------------------------------
# ******************************
# ______________________________
# Image ID : 047_0987
# Fitting now
# SSR = 1.087987e+05
# chi2dof = 8.355
# 1 Gaussian Model
#
# Center:	 (11.68, 16.43)
#
# Gaussian 1:
# Amplitude 1:	55.928
# VarX 1:	43.478
# VarY 1:	39.570
# Corr 1:	-0.299
#
#
# ----------------------------------------
# Max Gaussians = 10
# SSR = 1.087987e+05
# chi2dof = 8.393
# 2 Gaussians Model
#
# Center:	 (11.68, 16.43)
#
# Gaussian 1:
# Amplitude 1:	55.927
# VarX 1:	43.478
# VarY 1:	39.570
# Corr 1:	-0.299
#
# Gaussian 2:
# Amplitude 2:	11.346
# VarX 2:	0.000
# VarY 2:	2.283
# Corr 2:	0.091
#
#
# ----------------------------------------
# Old BE: 8.355	 New BE: 8.393
# Best model N = 1
# SSR = 1.087987e+05
# chi2dof = 8.355
# ------------------------------
# ******************************
# ______________________________
# Image ID : 047_1014
# Fitting now
# SSR = 3.185093e+05
# chi2dof = 58.640
# 1 Gaussian Model
#
# Center:	 (14.01, 13.60)
#
# Gaussian 1:
# Amplitude 1:	215.709
# VarX 1:	24.055
# VarY 1:	19.757
# Corr 1:	0.078
#
#
# ----------------------------------------
# Max Gaussians = 6
# SSR = 7.585634e+04
# chi2dof = 3.705
# 2 Gaussians Model
#
# Center:	 (14.27, 13.61)
#
# Gaussian 1:
# Amplitude 1:	130.166
# VarX 1:	39.340
# VarY 1:	33.118
# Corr 1:	0.059
#
# Gaussian 2:
# Amplitude 2:	251.894
# VarX 2:	2.761
# VarY 2:	2.404
# Corr 2:	0.026
#
#
# ----------------------------------------
# Old BE: 58.640	 New BE: 3.705
# SSR = 7.585634e+04
# chi2dof = 3.721
# 2 Gaussians Model
#
# Center:	 (14.27, 13.61)
#
# Gaussian 1:
# Amplitude 1:	130.162
# VarX 1:	39.342
# VarY 1:	33.119
# Corr 1:	0.059
#
# Gaussian 2:
# Amplitude 2:	143.270
# VarX 2:	2.761
# VarY 2:	2.404
# Corr 2:	0.026
#
# Gaussian 3:
# Amplitude 3:	108.626
# VarX 3:	2.761
# VarY 3:	2.404
# Corr 3:	0.026
#
#
# ----------------------------------------
# Old BE: 3.705	 New BE: 3.721
# Best model N = 2
# SSR = 7.585634e+04
# chi2dof = 3.705
# ------------------------------
# ******************************
# ______________________________
# Image ID : 047_0790
# Fitting now
# SSR = 7.290865e+04
# chi2dof = 4.290
# 1 Gaussian Model
#
# Center:	 (14.29, 14.93)
#
# Gaussian 1:
# Amplitude 1:	77.287
# VarX 1:	46.881
# VarY 1:	45.485
# Corr 1:	0.114
#
#
# ----------------------------------------
# Max Gaussians = 10
# SSR = 2.133072e+04
# chi2dof = 1.250
# 2 Gaussians Model
#
# Center:	 (14.82, 15.14)
#
# Gaussian 1:
# Amplitude 1:	44.640
# VarX 1:	85.732
# VarY 1:	84.273
# Corr 1:	0.091
#
# Gaussian 2:
# Amplitude 2:	82.772
# VarX 2:	7.099
# VarY 2:	5.519
# Corr 2:	0.127
#
#
# ----------------------------------------
# Old BE: 4.290	 New BE: 1.250
# SSR = 2.113317e+04
# chi2dof = 1.255
# 2 Gaussians Model
#
# Center:	 (14.82, 15.14)
#
# Gaussian 1:
# Amplitude 1:	43.541
# VarX 1:	87.848
# VarY 1:	86.435
# Corr 1:	0.096
#
# Gaussian 2:
# Amplitude 2:	22.708
# VarX 2:	4.270
# VarY 2:	3.100
# Corr 2:	0.519
#
# Gaussian 3:
# Amplitude 3:	64.399
# VarX 3:	8.263
# VarY 3:	6.595
# Corr 3:	0.039
#
#
# ----------------------------------------
# Old BE: 1.250	 New BE: 1.255
# Best model N = 2
# SSR = 2.133072e+04
# chi2dof = 1.250
# ------------------------------
# ******************************
# ______________________________
# Image ID : 047_1988
# Fitting now
# SSR = 1.969763e+05
# chi2dof = 1023.471
# 1 Gaussian Model
#
# Center:	 (14.65, 14.39)
#
# Gaussian 1:
# Amplitude 1:	240.224
# VarX 1:	16.488
# VarY 1:	16.951
# Corr 1:	-0.103
#
#
# ----------------------------------------
# Max Gaussians = 5
# SSR = 6.455002e+04
# chi2dof = 20.577
# 2 Gaussians Model
#
# Center:	 (14.51, 14.46)
#
# Gaussian 1:
# Amplitude 1:	152.591
# VarX 1:	26.236
# VarY 1:	26.236
# Corr 1:	-0.095
#
# Gaussian 2:
# Amplitude 2:	213.948
# VarX 2:	2.135
# VarY 2:	2.655
# Corr 2:	-0.002
#
#
# ----------------------------------------
# Old BE: 1023.471	 New BE: 20.577
# SSR = 6.329444e+04
# chi2dof = 26.616
# 2 Gaussians Model
#
# Center:	 (14.51, 14.46)
#
# Gaussian 1:
# Amplitude 1:	173.456
# VarX 1:	24.126
# VarY 1:	24.544
# Corr 1:	-0.058
#
# Gaussian 2:
# Amplitude 2:	-103.094
# VarX 2:	5.709
# VarY 2:	7.260
# Corr 2:	0.274
#
# Gaussian 3:
# Amplitude 3:	291.543
# VarX 3:	2.702
# VarY 3:	3.401
# Corr 3:	0.104
#
#
# ----------------------------------------
# Old BE: 20.577	 New BE: 26.616
# Best model N = 2
# SSR = 6.455002e+04
# chi2dof = 20.577
# ------------------------------
# ******************************
# ______________________________
# Image ID : 047_1846
# Fitting now
# SSR = 1.532678e+05
# chi2dof = 68123.652
# 1 Gaussian Model
#
# Center:	 (14.97, 4.06)
#
# Gaussian 1:
# Amplitude 1:	268.087
# VarX 1:	11.775
# VarY 1:	11.230
# Corr 1:	0.073
#
#
# ----------------------------------------
# Max Gaussians = 3
# SSR = 1.376943e+05
# chi2dof = 14741.162
# 2 Gaussians Model
#
# Center:	 (14.98, 4.04)
#
# Gaussian 1:
# Amplitude 1:	250.899
# VarX 1:	12.693
# VarY 1:	12.391
# Corr 1:	0.063
#
# Gaussian 2:
# Amplitude 2:	138.052
# VarX 2:	1.238
# VarY 2:	0.004
# Corr 2:	0.511
#
#
# ----------------------------------------
# Old BE: 68123.652	 New BE: 14741.162
# SSR = 1.532678e+05
# chi2dof = 69064.018
# 2 Gaussians Model
#
# Center:	 (14.97, 4.06)
#
# Gaussian 1:
# Amplitude 1:	268.087
# VarX 1:	11.775
# VarY 1:	11.230
# Corr 1:	0.073
#
# Gaussian 2:
# Amplitude 2:	18.554
# VarX 2:	0.000
# VarY 2:	0.000
# Corr 2:	0.006
#
# Gaussian 3:
# Amplitude 3:	29.579
# VarX 3:	0.001
# VarY 3:	0.000
# Corr 3:	-0.002
#
#
# ----------------------------------------
# Old BE: 14741.162	 New BE: 69064.018
# Best model N = 2
# SSR = 1.376943e+05
# chi2dof = 14741.162
# ------------------------------
# ******************************
# ______________________________
# Image ID : 047_0118
# Fitting now
# SSR = 1.122787e+06
# chi2dof = 352.409
# 1 Gaussian Model
#
# Center:	 (14.01, 14.48)
#
# Gaussian 1:
# Amplitude 1:	377.771
# VarX 1:	21.073
# VarY 1:	18.473
# Corr 1:	0.008
#
#
# ----------------------------------------
# Max Gaussians = 6
# SSR = 3.589213e+05
# chi2dof = 8.127
# 2 Gaussians Model
#
# Center:	 (14.30, 14.43)
#
# Gaussian 1:
# Amplitude 1:	125.829
# VarX 1:	71.856
# VarY 1:	54.753
# Corr 1:	0.084
#
# Gaussian 2:
# Amplitude 2:	417.898
# VarX 2:	5.594
# VarY 2:	5.773
# Corr 2:	0.041
#
#
# ----------------------------------------
# Old BE: 352.409	 New BE: 8.127
# SSR = 3.505623e+05
# chi2dof = 8.111
# 2 Gaussians Model
#
# Center:	 (14.30, 14.45)
#
# Gaussian 1:
# Amplitude 1:	113.875
# VarX 1:	81.613
# VarY 1:	55.444
# Corr 1:	0.137
#
# Gaussian 2:
# Amplitude 2:	81.374
# VarX 2:	8.993
# VarY 2:	19.224
# Corr 2:	-0.407
#
# Gaussian 3:
# Amplitude 3:	355.184
# VarX 3:	5.540
# VarY 3:	4.681
# Corr 3:	0.157
#
#
# ----------------------------------------
# Old BE: 8.127	 New BE: 8.111
# SSR = 3.486241e+05
# chi2dof = 8.085
# 2 Gaussians Model
#
# Center:	 (14.31, 14.45)
#
# Gaussian 1:
# Amplitude 1:	112.480
# VarX 1:	82.518
# VarY 1:	54.553
# Corr 1:	0.165
#
# Gaussian 2:
# Amplitude 2:	28.818
# VarX 2:	19.982
# VarY 2:	42.062
# Corr 2:	-0.687
#
# Gaussian 3:
# Amplitude 3:	276.110
# VarX 3:	5.781
# VarY 3:	7.339
# Corr 3:	0.030
#
# Gaussian 4:
# Amplitude 4:	139.249
# VarX 4:	5.367
# VarY 4:	2.587
# Corr 4:	0.275
#
#
# ----------------------------------------
# Old BE: 8.111	 New BE: 8.085
# SSR = 3.481772e+05
# chi2dof = 8.127
# 2 Gaussians Model
#
# Center:	 (14.31, 14.45)
#
# Gaussian 1:
# Amplitude 1:	112.063
# VarX 1:	82.923
# VarY 1:	54.655
# Corr 1:	0.165
#
# Gaussian 2:
# Amplitude 2:	257.218
# VarX 2:	5.632
# VarY 2:	7.700
# Corr 2:	0.045
#
# Gaussian 3:
# Amplitude 3:	29.230
# VarX 3:	19.845
# VarY 3:	41.832
# Corr 3:	-0.696
#
# Gaussian 4:
# Amplitude 4:	29.259
# VarX 4:	4.891
# VarY 4:	3.812
# Corr 4:	0.820
#
# Gaussian 5:
# Amplitude 5:	133.809
# VarX 5:	6.145
# VarY 5:	2.708
# Corr 5:	0.097
#
#
# ----------------------------------------
# Old BE: 8.085	 New BE: 8.127
# Best model N = 4
# SSR = 3.486241e+05
# chi2dof = 8.085
# ------------------------------
# ******************************
# ______________________________
# Image ID : 047_0855
# Fitting now
# SSR = 1.619441e+05
# chi2dof = 10.757
# 1 Gaussian Model
#
# Center:	 (14.11, 14.77)
#
# Gaussian 1:
# Amplitude 1:	118.011
# VarX 1:	42.424
# VarY 1:	31.727
# Corr 1:	0.126
#
#
# ----------------------------------------
# Max Gaussians = 10
# SSR = 8.398982e+04
# chi2dof = 3.737
# 2 Gaussians Model
#
# Center:	 (13.85, 14.64)
#
# Gaussian 1:
# Amplitude 1:	89.949
# VarX 1:	55.810
# VarY 1:	42.542
# Corr 1:	0.103
#
# Gaussian 2:
# Amplitude 2:	132.733
# VarX 2:	2.843
# VarY 2:	1.859
# Corr 2:	0.238
#
#
# ----------------------------------------
# Old BE: 10.757	 New BE: 3.737
# SSR = 8.285851e+04
# chi2dof = 3.786
# 2 Gaussians Model
#
# Center:	 (13.84, 14.64)
#
# Gaussian 1:
# Amplitude 1:	90.556
# VarX 1:	55.530
# VarY 1:	42.290
# Corr 1:	0.104
#
# Gaussian 2:
# Amplitude 2:	-8183.544
# VarX 2:	1.834
# VarY 2:	1.163
# Corr 2:	0.322
#
# Gaussian 3:
# Amplitude 3:	8300.156
# VarX 3:	1.851
# VarY 3:	1.175
# Corr 3:	0.320
#
#
# ----------------------------------------
# Old BE: 3.737	 New BE: 3.786
# Best model N = 2
# SSR = 8.398982e+04
# chi2dof = 3.737
# ------------------------------
# ******************************
# ______________________________
# Image ID : 047_1866
# Fitting now
# SSR = 8.556913e+04
# chi2dof = 20.941
# 1 Gaussian Model
#
# Center:	 (13.83, 13.65)
#
# Gaussian 1:
# Amplitude 1:	111.632
# VarX 1:	27.374
# VarY 1:	30.406
# Corr 1:	0.137
#
#
# ----------------------------------------
# Max Gaussians = 9
# SSR = 5.376849e+04
# chi2dof = 6.325
# 2 Gaussians Model
#
# Center:	 (14.02, 14.10)
#
# Gaussian 1:
# Amplitude 1:	87.757
# VarX 1:	34.967
# VarY 1:	38.495
# Corr 1:	0.106
#
# Gaussian 2:
# Amplitude 2:	96.159
# VarX 2:	2.495
# VarY 2:	1.737
# Corr 2:	0.060
#
#
# ----------------------------------------
# Old BE: 20.941	 New BE: 6.325
# SSR = 5.138320e+04
# chi2dof = 4.897
# 2 Gaussians Model
#
# Center:	 (13.99, 14.10)
#
# Gaussian 1:
# Amplitude 1:	80.042
# VarX 1:	35.964
# VarY 1:	41.790
# Corr 1:	0.059
#
# Gaussian 2:
# Amplitude 2:	27.405
# VarX 2:	16.678
# VarY 2:	6.970
# Corr 2:	0.727
#
# Gaussian 3:
# Amplitude 3:	77.838
# VarX 3:	1.896
# VarY 3:	1.670
# Corr 3:	-0.181
#
#
# ----------------------------------------
# Old BE: 6.325	 New BE: 4.897
# SSR = 4.163563e+04
# chi2dof = 1.812
# 2 Gaussians Model
#
# Center:	 (13.97, 14.10)
#
# Gaussian 1:
# Amplitude 1:	21.107
# VarX 1:	181.428
# VarY 1:	55.673
# Corr 1:	-0.549
#
# Gaussian 2:
# Amplitude 2:	22.657
# VarX 2:	36.381
# VarY 2:	5.760
# Corr 2:	0.753
#
# Gaussian 3:
# Amplitude 3:	68.916
# VarX 3:	19.404
# VarY 3:	42.294
# Corr 3:	0.314
#
# Gaussian 4:
# Amplitude 4:	72.983
# VarX 4:	1.683
# VarY 4:	1.493
# Corr 4:	-0.185
#
#
# ----------------------------------------
# Old BE: 4.897	 New BE: 1.812
# Max Evals exceeded for 5 Gaussians
# 2 Gaussians Model
#
# Center:	 (0.00, 0.00)
#
# Gaussian 1:
# Amplitude 1:	0.000
# VarX 1:	0.000
# VarY 1:	0.000
# Corr 1:	0.000
#
# Gaussian 2:
# Amplitude 2:	0.000
# VarX 2:	0.000
# VarY 2:	0.000
# Corr 2:	0.000
#
# Gaussian 3:
# Amplitude 3:	0.000
# VarX 3:	0.000
# VarY 3:	0.000
# Corr 3:	0.000
#
# Gaussian 4:
# Amplitude 4:	0.000
# VarX 4:	0.000
# VarY 4:	0.000
# Corr 4:	0.000
#
# Gaussian 5:
# Amplitude 5:	0.000
# VarX 5:	0.000
# VarY 5:	0.000
# Corr 5:	0.000
#
#
# ----------------------------------------
# NaN raised for Gaussian 5
# Best model N = 4
# SSR = 4.163563e+04
# chi2dof = 1.812
# ------------------------------
# ******************************
# ______________________________
# Image ID : 072_2003
# Fitting now
# SSR = 2.633878e+05
# chi2dof = 40.979
# 1 Gaussian Model
#
# Center:	 (14.25, 14.13)
#
# Gaussian 1:
# Amplitude 1:	330.679
# VarX 1:	25.471
# VarY 1:	20.970
# Corr 1:	0.110
#
#
# ----------------------------------------
# Max Gaussians = 7
# SSR = 6.501142e+04
# chi2dof = 2.973
# 2 Gaussians Model
#
# Center:	 (14.27, 14.05)
#
# Gaussian 1:
# Amplitude 1:	196.234
# VarX 1:	40.709
# VarY 1:	34.345
# Corr 1:	0.153
#
# Gaussian 2:
# Amplitude 2:	235.284
# VarX 2:	6.223
# VarY 2:	4.562
# Corr 2:	0.017
#
#
# ----------------------------------------
# Old BE: 40.979	 New BE: 2.973
# SSR = 5.185299e+04
# chi2dof = 1.264
# 2 Gaussians Model
#
# Center:	 (14.27, 14.05)
#
# Gaussian 1:
# Amplitude 1:	33.431
# VarX 1:	157.260
# VarY 1:	98.838
# Corr 1:	0.544
#
# Gaussian 2:
# Amplitude 2:	217.081
# VarX 2:	26.079
# VarY 2:	22.747
# Corr 2:	0.050
#
# Gaussian 3:
# Amplitude 3:	193.200
# VarX 3:	4.311
# VarY 3:	3.210
# Corr 3:	0.031
#
#
# ----------------------------------------
# Old BE: 2.973	 New BE: 1.264
# SSR = 5.420595e+04
# chi2dof = 1.892
# 2 Gaussians Model
#
# Center:	 (14.27, 14.05)
#
# Gaussian 1:
# Amplitude 1:	157.970
# VarX 1:	47.239
# VarY 1:	38.595
# Corr 1:	0.204
#
# Gaussian 2:
# Amplitude 2:	191.378
# VarX 2:	11.076
# VarY 2:	5.225
# Corr 2:	0.279
#
# Gaussian 3:
# Amplitude 3:	70.335
# VarX 3:	7.635
# VarY 3:	20.971
# Corr 3:	-0.700
#
# Gaussian 4:
# Amplitude 4:	114.762
# VarX 4:	0.983
# VarY 4:	0.001
# Corr 4:	-0.331
#
#
# ----------------------------------------
# Old BE: 1.264	 New BE: 1.892
# Best model N = 3
# SSR = 5.185299e+04
# chi2dof = 1.264
# /usr/local/lib/python2.7/dist-packages/scipy/optimize/minpack.py:604: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)

# %% [markdown]
# One note before moving onto the other features. This module also supports Gooey, which automatically generates a simple user interface to insert the inputs, which is much easier to use than remembering all the command line options. However, there are currently a few bugs so I've disabled it from the standard distribution. I have designed it to be easily turned on. In the "modelImages.py" module change `gooeyOn` to `True` and uncomment the decorator above the main function, and you're all set to use the Gooey GUI!
#
# There are two additional programs of interest with this module that are comparatively much simpler. The first is the makeCenterFile.py module.

# %%
# %%bash
# python ../src/makeCenterFile.py -h
# Out:
# usage: makeCenterFile.py [-h]
#                          dirname catalog centerFilename [ra_idx] [run_idx]
#
# This is a helper function that is not called by the main modeling function. It
# converts the Ra, Dec of an object into pixel coordinates, and saves that file
# in the right format In the directory. That file is the "centers" file used in
# the main modeler.
#
# positional arguments:
#   dirname         Directory from which to read the .fits files and to write
#                   the output file.
#   catalog         File where the informatoin regarding the .fits images is
#                   located.
#   centerFilename  File to write the output to.
#   ra_idx          Index of the ra in the catalog along a line. Assumed to be
#                   followed by dec.
#   run_idx         Index of the run in the catalog along a line. Assumed to be
#                   followed by rerun, camcol, and field.
#
# optional arguments:
#   -h, --help      show this help message and exit

# %% [markdown]
# This module does what it says in its description: it converts a Ra,Dec and Run, Camcol, Field into a center file the program can accept as input. Note that for one Run, Camcol, and Field the program can currently only accept 1 object at a time. **Dirname** is the directory with the images, and **catalog** is the file that contains the ra, dec and run camcol field. It's assumed the filename of the image is in the standard SDSS pattern of [run]-[camcol]-[field].fits. **ra_idx** and run_**idx** are the location in the catalog of the ra and run information.The line of the file will be split by whitespace, and index is the column number (0-based indexing). And lastly, **centerFilename** is the location to save the file to.

# %%
# %%bash
# python ../src/makeToyImages.py -h
# Out:
# usage: makeToyImages.py [-h] [--noNoise] dirname N
#
# This module makes given number of "toy" images, which are actual mixtures of
# Gaussians with various noise filters overlaid. It also saves the true
# parameters of the model in a file so they can be compared.
#
# positional arguments:
#   dirname     Directory to save the produces images to.
#   N           Number of images to create.
#
# optional arguments:
#   -h, --help  show this help message and exit
#   --noNoise   Save images with no noise.

# %% [markdown]
# This module simply creates some dummy images to test the modeler against. **dirname** is the directory to save them, **N** is how many to make, and the optional flag **--noNoise** makes, you guessed it, images with no added noise.
